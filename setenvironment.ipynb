# %%
# !pip install transformers pillow torch gTTS moviepy tqdm

# %%
captioner = pipeline("image-to-text",model="Salesforce/blip-image-captioning-base")

# %%
# !git clone https://github.com/jantic/DeOldify.git DeOldify
# !pip install -r DeOldify/requirements-colab.txt

# %%
pip install deoldify

# %%
from deoldify import device
from deoldify.device_id import DeviceId

device.set(device=DeviceId.GPU0)

import fastai
from deoldify.visualize import *
import warnings
warnings.filterwarnings("ignore", category=UserWarning, message=".*?Your .*? set is empty.*?")

# %%
# !mkdir 'models'
# !wget https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth -O ./models/ColorizeArtistic_gen.pth

# %%
colorizer = get_image_colorizer(artistic=True)

# %% [markdown]
# # test

# %%
captioner("https://huggingface.co/datasets/Narsil/image_dummy/resolve/main/parrots.png")

# %%
image_path="input.jpg"
colorizer.plot_transformed_image(path=image_path, render_factor=35, figsize=(20, 20))
# Out:
# [ WARN:0@376.349] global loadsave.cpp:248 findDecoder imread_('./resource_images/watermark.png'): can't open/read file: check file path/integrity
# PosixPath('result_images/20231216_CUP501.jpg')
